# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('D:\\Inceptez\\train_v9rqX0R.csv')

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
data.describe(include='all').T
# Out:
#                           count unique                    top  freq      mean  \
# Item_Identifier            8523   1559                  FDW13    10       NaN
# Item_Weight                7060    NaN                    NaN   NaN   12.8576
# Item_Fat_Content           8523      5                Low Fat  5089       NaN
# Item_Visibility            8523    NaN                    NaN   NaN  0.066132
# Item_Type                  8523     16  Fruits and Vegetables  1232       NaN
# Item_MRP                   8523    NaN                    NaN   NaN   140.993
# Outlet_Identifier          8523     10                 OUT027   935       NaN
# Outlet_Establishment_Year  8523    NaN                    NaN   NaN   1997.83
# Outlet_Size                6113      3                 Medium  2793       NaN
# Outlet_Location_Type       8523      3                 Tier 3  3350       NaN
# Outlet_Type                8523      4      Supermarket Type1  5577       NaN
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# ## To see what are the rows that has Item_Weight as Nan

# %%
series = pd.isnull(data['Item_Weight'])
data[series]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7              FDP10          NaN          Low Fat         0.127470
# 18             DRI11          NaN          Low Fat         0.034238
# 21             FDW12          NaN          Regular         0.035400
# 23             FDC37          NaN          Low Fat         0.057557
# 29             FDC14          NaN          Regular         0.072222
# ...              ...          ...              ...              ...
# 8485           DRK37          NaN          Low Fat         0.043792
# 8487           DRG13          NaN          Low Fat         0.037006
# 8488           NCN14          NaN          Low Fat         0.091473
# 8490           FDU44          NaN          Regular         0.102296
# 8504           NCN18          NaN          Low Fat         0.124111
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 7               Snack Foods  107.7622            OUT027
# ...

# %%
data["Item_Weight"].fillna(data["Item_Weight"].mean(), inplace = True)

# %%
data.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
data["Outlet_Size"].fillna(data["Outlet_Size"].mode()[0], inplace = True)

# %%
data.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
#Script to find the outliers
for col_name in data.select_dtypes(include=np.number).columns[:-1]:
    print(col_name)
    q1 = data[col_name].quantile(0.25)
    q3 = data[col_name].quantile(0.75)
    iqr = q3 - q1
    
    low = q1-1.5*iqr
    high = q3+1.5*iqr
    print("Outliers = ",data.loc[(data[col_name] < low) | (data[col_name] > high), col_name])
# Out:
# Item_Weight
# Outliers =  Series([], Name: Item_Weight, dtype: float64)
# Item_Visibility
# Outliers =  49      0.255395
# 83      0.293418
# 108     0.278974
# 174     0.291865
# 334     0.204700
#           ...
# 8292    0.209163
# 8345    0.266397
# 8371    0.214125
# 8432    0.227261
# 8509    0.214306
# Name: Item_Visibility, Length: 144, dtype: float64
# Item_MRP
# Outliers =  Series([], Name: Item_MRP, dtype: float64)
# Outlet_Establishment_Year
# Outliers =  Series([], Name: Outlet_Establishment_Year, dtype: int64)

# %%
data.select_dtypes(exclude=np.number)
# Out:
#      Item_Identifier Item_Fat_Content              Item_Type  \
# 0              FDA15          Low Fat                  Dairy
# 1              DRC01          Regular            Soft Drinks
# 2              FDN15          Low Fat                   Meat
# 3              FDX07          Regular  Fruits and Vegetables
# 4              NCD19          Low Fat              Household
# ...              ...              ...                    ...
# 8518           FDF22          Low Fat            Snack Foods
# 8519           FDS36          Regular           Baking Goods
# 8520           NCJ29          Low Fat     Health and Hygiene
# 8521           FDN46          Regular            Snack Foods
# 8522           DRG01          Low Fat            Soft Drinks
#
#      Outlet_Identifier Outlet_Size Outlet_Location_Type        Outlet_Type
# 0               OUT049      Medium               Tier 1  Supermarket Type1
# 1               OUT018      Medium               Tier 3  Supermarket Type2
# ...

# %%
data['Outlet_Size'].value_counts()
# Out:
# Medium    5203
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
data['Outlet_Size'].replace({'High':2,
                             'Medium':1,
                             'Small':0
                            },inplace=True)

# %%
data['Outlet_Size'].value_counts()
# Out:
# 1    5203
# 0    2388
# 2     932
# Name: Outlet_Size, dtype: int64

# %%
data['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
data['Item_Fat_Content'].replace({'LF':'Low Fat',
                             'reg':'Regular',
                             'low fat':'Low Fat'
                            },inplace=True)

# %%
data['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %%
data['Item_Fat_Content'].replace({'Low Fat':0,
                             'Regular':1,
                             },inplace=True)

# %%
data['Item_Fat_Content'].value_counts()
# Out:
# 0    5517
# 1    3006
# Name: Item_Fat_Content, dtype: int64

# %%
data['Item_Type'].value_counts()
# Out:
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64

# %%
data['Item_Identifier'].value_counts()
# Out:
# FDW13    10
# FDG33    10
# DRE49     9
# NCF42     9
# FDQ40     9
#          ..
# FDQ60     1
# DRF48     1
# FDN52     1
# FDC23     1
# FDK57     1
# Name: Item_Identifier, Length: 1559, dtype: int64

# %%
data['Outlet_Identifier'].value_counts()
# Out:
# OUT027    935
# OUT013    932
# OUT035    930
# OUT046    930
# OUT049    930
# OUT045    929
# OUT018    928
# OUT017    926
# OUT010    555
# OUT019    528
# Name: Outlet_Identifier, dtype: int64

# %%
data['Outlet_Identifier'].replace({'OUT010':0,
                                   'OUT013':1,
                                   'OUT017':2,
                                   'OUT018':3,
                                   'OUT019':4,
                                   'OUT027':5,
                                   'OUT035':6,
                                   'OUT045':7,
                                   'OUT046':8,
                                   'OUT049':6,                        
                                    },inplace=True)

# %%
data['Outlet_Identifier'].value_counts()
# Out:
# 6    1860
# 5     935
# 1     932
# 8     930
# 7     929
# 3     928
# 2     926
# 0     555
# 4     528
# Name: Outlet_Identifier, dtype: int64

# %%
data['Outlet_Location_Type'].value_counts()
# Out:
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: Outlet_Location_Type, dtype: int64

# %%
data['Outlet_Location_Type'].replace({'Tier 3':2,
                             'Tier 2':1,
                             'Tier 1':0
                            },inplace=True)

# %%
data['Outlet_Location_Type'].value_counts()
# Out:
# 2    3350
# 1    2785
# 0    2388
# Name: Outlet_Location_Type, dtype: int64

# %%
data['Outlet_Type'].value_counts()
# Out:
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64

# %%
data['Outlet_Type'].replace({'Supermarket Type3':3,
                             'Supermarket Type2':2,
                             'Supermarket Type1':1,
                             'Grocery Store': 0
                            },inplace=True)

# %%
data['Outlet_Type'].value_counts()
# Out:
# 1    5577
# 0    1083
# 3     935
# 2     928
# Name: Outlet_Type, dtype: int64

# %%
data['Outlet_Establishment_Year'].value_counts()
# Out:
# 1985    1463
# 1987     932
# 1999     930
# 1997     930
# 2004     930
# 2002     929
# 2009     928
# 2007     926
# 1998     555
# Name: Outlet_Establishment_Year, dtype: int64

# %%
data['Outlet_Establishment_Year'].replace({1985:0,
                                           1987:1,
                                           1998:2,
                                           1997:3,
                                           1999:4,
                                           2002:5,
                                           2004:6,
                                           2007:7,
                                           2009:8,
                                           },inplace=True)

# %%
data['Outlet_Establishment_Year'].value_counts()
# Out:
# 0    1463
# 1     932
# 6     930
# 4     930
# 3     930
# 5     929
# 8     928
# 7     926
# 2     555
# Name: Outlet_Establishment_Year, dtype: int64

# %%
data.select_dtypes(include=np.number)
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_MRP  \
# 0           9.300                 0         0.016047  249.8092
# 1           5.920                 1         0.019278   48.2692
# 2          17.500                 0         0.016760  141.6180
# 3          19.200                 1         0.000000  182.0950
# 4           8.930                 0         0.000000   53.8614
# ...           ...               ...              ...       ...
# 8518        6.865                 0         0.056783  214.5218
# 8519        8.380                 1         0.046982  108.1570
# 8520       10.600                 0         0.035186   85.1224
# 8521        7.210                 1         0.145221  103.1332
# 8522       14.800                 0         0.044878   75.4670
#
#       Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0                     6                          4            1
# 1                     3                          8            1
# ...

# %%
numerical_data = data.select_dtypes(include=np.number).drop(columns=['Item_Fat_Content','Outlet_Size','Outlet_Type',
                                                                     'Outlet_Location_Type','Outlet_Establishment_Year',
                                                                    'Outlet_Identifier'])

# %%
numerical_data
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Item_Outlet_Sales
# 0           9.300         0.016047  249.8092          3735.1380
# 1           5.920         0.019278   48.2692           443.4228
# 2          17.500         0.016760  141.6180          2097.2700
# 3          19.200         0.000000  182.0950           732.3800
# 4           8.930         0.000000   53.8614           994.7052
# ...           ...              ...       ...                ...
# 8518        6.865         0.056783  214.5218          2778.3834
# 8519        8.380         0.046982  108.1570           549.2850
# 8520       10.600         0.035186   85.1224          1193.1136
# 8521        7.210         0.145221  103.1332          1845.5976
# 8522       14.800         0.044878   75.4670           765.6700
#
# [8523 rows x 4 columns]

# %%
categorical_data = data.select_dtypes(exclude=np.number)

# %%
categorical_data
# Out:
#      Item_Identifier              Item_Type
# 0              FDA15                  Dairy
# 1              DRC01            Soft Drinks
# 2              FDN15                   Meat
# 3              FDX07  Fruits and Vegetables
# 4              NCD19              Household
# ...              ...                    ...
# 8518           FDF22            Snack Foods
# 8519           FDS36           Baking Goods
# 8520           NCJ29     Health and Hygiene
# 8521           FDN46            Snack Foods
# 8522           DRG01            Soft Drinks
#
# [8523 rows x 2 columns]

# %%
categorical_data_processed = pd.get_dummies(categorical_data)

# %%
categorical_data_processed
# Out:
#       Item_Identifier_DRA12  Item_Identifier_DRA24  Item_Identifier_DRA59  \
# 0                         0                      0                      0
# 1                         0                      0                      0
# 2                         0                      0                      0
# 3                         0                      0                      0
# 4                         0                      0                      0
# ...                     ...                    ...                    ...
# 8518                      0                      0                      0
# 8519                      0                      0                      0
# 8520                      0                      0                      0
# 8521                      0                      0                      0
# 8522                      0                      0                      0
#
#       Item_Identifier_DRB01  Item_Identifier_DRB13  Item_Identifier_DRB24  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
std_scale = StandardScaler()
df_std = std_scale.fit_transform(numerical_data)

# %%
numerical_data_preprocessed = pd.DataFrame(df_std,columns = numerical_data.columns)

# %% [markdown]
# numerical_data_preprocessed

# %%
pre_processed_data = pd.concat([categorical_data_processed,numerical_data_preprocessed,
                                data['Item_Fat_Content'], 
                                data['Outlet_Size'],
                                data['Outlet_Type'],
                                data['Outlet_Location_Type'],
                                data['Outlet_Establishment_Year'],
                                data['Outlet_Identifier']], axis = 1)

# %%
pre_processed_data
# Out:
#       Item_Identifier_DRA12  Item_Identifier_DRA24  Item_Identifier_DRA59  \
# 0                         0                      0                      0
# 1                         0                      0                      0
# 2                         0                      0                      0
# 3                         0                      0                      0
# 4                         0                      0                      0
# ...                     ...                    ...                    ...
# 8518                      0                      0                      0
# 8519                      0                      0                      0
# 8520                      0                      0                      0
# 8521                      0                      0                      0
# 8522                      0                      0                      0
#
#       Item_Identifier_DRB01  Item_Identifier_DRB13  Item_Identifier_DRB24  \
# ...
